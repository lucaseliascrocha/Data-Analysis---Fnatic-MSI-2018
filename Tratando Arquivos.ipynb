# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


df = pd.read_excel('fnatic_msi.xlsx')
df.head(6)
# Out:
#   position     player    team  champion   ban1     ban2   ban3  ban4  ban5  \
# 0      Top      Bwipo  Fnatic  Vladimir  Karma  Morgana  Rakan  Shen  Lulu
# 1   Jungle     Broxah  Fnatic   Trundle  Karma  Morgana  Rakan  Shen  Lulu
# 2   Middle       Caps  Fnatic     Yasuo  Karma  Morgana  Rakan  Shen  Lulu
# 3      ADC    Rekkles  Fnatic    Kai'Sa  Karma  Morgana  Rakan  Shen  Lulu
# 4  Support  Hylissang  Fnatic     Braum  Karma  Morgana  Rakan  Shen  Lulu
# 5     Team       Team  Fnatic         ?  Karma  Morgana  Rakan  Shen  Lulu
#
#    gamelength   ...    gdat15  xpat10  oppxpat10  xpdat10  csat10  oppcsat10  \
# 0   36.383333   ...      -386    4706       4883     -177      83         99
# 1   36.383333   ...       106    3779       3721       58      62         66
# 2   36.383333   ...      -221    4700       4731      -31      88         97
# 3   36.383333   ...     -1119    3395       3123      272      90         94
# ...

# %%
bans = df.query('position == "Team"')
bans = bans.loc[:,'ban1':'ban5']
for id, row in bans.iterrows():
    print(row)
# Out:
# ban1      Karma
# ban2    Morgana
# ban3      Rakan
# ban4       Shen
# ban5       Lulu
# Name: 5, dtype: object
# ban1     Kai'sa
# ban2      Rakan
# ban3      Karma
# ban4    Camille
# ban5       Gnar
# Name: 11, dtype: object
# ban1        Ezreal
# ban2    Tahm Kench
# ban3          Olaf
# ban4       Sejuani
# ban5        Graves
# Name: 17, dtype: object
# ban1       Graves
# ban2      Morgana
# ban3    Gangplank
# ban4         Ornn
# ban5     Vladimir
# Name: 23, dtype: object
# ban1     Graves
# ban2     Kai'Sa
# ban3       Ornn
# ban4    Kha'zix
# ban5    Taliyah
# Name: 29, dtype: object
# ban1     Kog'Maw
# ban2      Kai'Sa
# ban3    Vladimir
# ban4        Shen
# ban5       Karma
# Name: 35, dtype: object
# ban1    Kha'zix
# ban2     Graves
# ban3      Rakan
# ban4     Soraka
# ban5      Janna
# Name: 41, dtype: object
# ban1    Morgana
# ban2    Trundle
# ban3     Kai'Sa
# ban4       Shen
# ban5     Singed
# Name: 47, dtype: object
# ban1    Tahm Kench
# ban2         Rakan
# ...
